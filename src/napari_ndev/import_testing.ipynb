# %%
from aicsimageio.types import PhysicalPixelSizes

# %%
from aicsimageio import AICSImage

# %%
from aicsimageio.writers import OmeTiffWriter

# %%
import napari_ndev

# %%
napari_ndev.helpers.get_channel_names
# Out:
# <function napari_ndev.helpers.get_channel_names(img: 'AICSImage') -> List[str]>

# %%
from napari_ndev import helpers

# %%
helpers.get_channel_names(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 helpers.get_channel_names(img)
#
# NameError: name 'img' is not defined

# %%
from napari_ndev import helpers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from napari_ndev import helpers
#
# File ~\napari-ndev\src\napari_ndev\helpers.py:62
#      58             files.append(file)
#      59     return directory, files
# ---> 62 def get_channel_names(img: AICSImage) -> List[str]:
#      63     """
#      64     Get the channel names from an AICSImage object.
#      65
#    (...)
#      74         List[str]: The channel names.
#      75     """
#      76     if "S" in img.dims.order:
#
# NameError: name 'AICSImage' is not defined

# %%
from aicsimageio import AICSImage

# %%
from napari_ndev import helpers

# %%
from napari_ndev import helpers

# %%
from napari_ndev import helpers

# %%
helpers.check_for_missing_files
# Out:
# <function napari_ndev.helpers.check_for_missing_files(files: List[pathlib.Path], *directories: pathlib.Path) -> List[tuple]>

# %%
import napari_ndev

# %%
from skimage import filters

# %%
filters.sobel

# %%
from napari_ndev import ApocContainer

# %%
from napari_ndev import helpers

# %%
from napari_ndev import ApocContainer

# %%
import aicsimageio

# %%
import napari_ndev._plate_mapper
napari_ndev._plate_mapper.PlateMapper()

# %%
import napari_ndev._rescale_by

# %%
import napari_ndev._apoc_container

# %%
import napari_ndev

# %%
napari_ndev._apoc_container.ApocContainer

# %%
import cProfile
import pstats

def import_my_library():
    import napari_ndev  # Replace 'magicgui' with the name of your library

# Profile the import
cProfile.run('import_my_library()', 'import_profile')

# Read the stats
stats = pstats.Stats('import_profile')
stats.sort_stats('time').print_stats()
# Out:
# Fri Jun 21 17:12:28 2024    import_profile
#
#          6545382 function calls (6222322 primitive calls) in 4.132 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      3214    0.348    0.000    0.348    0.000 {built-in method io.open_code}
#      3214    0.256    0.000    0.256    0.000 {built-in method marshal.loads}
#     14242    0.218    0.000    0.218    0.000 {built-in method nt.stat}
# 5473/4577    0.145    0.000    1.035    0.000 {built-in method builtins.__build_class__}
#     16984    0.129    0.000    0.129    0.000 {built-in method builtins.compile}
#   282/275    0.115    0.000    0.119    0.000 {built-in method _imp.create_dynamic}
#     25187    0.093    0.000    0.141    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
# 944312/944062    0.078    0.000    0.087    0.000 {built-in method builtins.isinstance}
#      3738    0.073    0.000    0.082    0.000 {built-in method io.open}
# ...

# %%
import aicsimageio

# %%
import magicgui

# %%
import napari_ndev

# %%
napari_ndev.helpers.asdf

# %%
import seaborn as sns

# %%
napari_ndev.helpers.check_for_missing_files
# Out:
# <function napari_ndev.helpers.check_for_missing_files(files: List[pathlib.Path], *directories: pathlib.Path) -> List[tuple]>

# %%
napari_ndev.helpers.__all__
# Out:
# ['check_for_missing_files',
#  'get_channel_names',
#  'get_directory_and_files',
#  'get_squeezed_dim_order',
#  'setup_logger']

# %%
napari_ndev.helpers.
# Out:
# <module 'napari_ndev.helpers' from 'C:\\Users\\ImageAnalysis\\napari-ndev\\src\\napari_ndev\\helpers.py'>

# %%
from napari_ndev import helpers

# %%
helpers.__all__
# Out:
# ['check_for_missing_files',
#  'get_channel_names',
#  'get_directory_and_files',
#  'get_squeezed_dim_order',
#  'setup_logger']

# %%
napari_ndev.helpers.get_squeezed_dim_order
# Out:
# <module 'napari_ndev.helpers' from 'C:\\Users\\ImageAnalysis\\napari-ndev\\src\\napari_ndev\\helpers.py'>

# %%
napari_ndev.helpers.AICSImage
# Out:
# aicsimageio.aics_image.AICSImage

# %%
import napari_ndev

# %%
napari_ndev.PlateMapper
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 napari_ndev.PlateMapper()
#
# TypeError: 'LazyImport' object is not callable

# %%
from napari_ndev import *

# %%
plate = PlateMapper.PlateMapper(96)
plate.plate_map
# Out:
#    Row  Column Well ID
# 0    A       1      A1
# 1    A       2      A2
# 2    A       3      A3
# 3    A       4      A4
# 4    A       5      A5
# ..  ..     ...     ...
# 91   H       8      H8
# 92   H       9      H9
# 93   H      10     H10
# 94   H      11     H11
# 95   H      12     H12
#
# [96 rows x 3 columns]

# %%
import napari_ndev._plate_mapper


napari_ndev._plate_mapper.PlateMapper(96)

# %%
napari_ndev.PlateMapper

# %%
import cProfile

cProfile.run('import napari_ndev', sort = 'cumulative')
# Out:
#          1178 function calls (1171 primitive calls) in 0.002 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       3/1    0.000    0.000    0.002    0.002 {built-in method builtins.exec}
#         1    0.000    0.000    0.002    0.002 <string>:1(<module>)
#       2/1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:1022(_find_and_load)
#       2/1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:987(_find_and_load_unlocked)
#       2/1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:664(_load_unlocked)
#       2/1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:877(exec_module)
#         2    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:921(_find_spec)
#         2    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1431(find_spec)
# ...

# %%
prof = cProfile.Profile('import napari_ndev')
prof.print_stats()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 prof = cProfile.Profile('import napari_ndev')
# ----> 2 prof.print_stats()
#
# File c:\Users\ImageAnalysis\mambaforge\envs\bastian-lab\lib\cProfile.py:42, in Profile.print_stats(self, sort)
#      40 def print_stats(self, sort=-1):
#      41     import pstats
# ---> 42     pstats.Stats(self).strip_dirs().sort_stats(sort).print_stats()
#
# File c:\Users\ImageAnalysis\mambaforge\envs\bastian-lab\lib\pstats.py:114, in Stats.__init__(self, stream, *args)
#     112     arg = args[0]
#     113     args = args[1:]
# --> 114 self.init(arg)
#     115 self.add(*args)
#
# File c:\Users\ImageAnalysis\mambaforge\envs\bastian-lab\lib\pstats.py:128, in Stats.init(self, arg)
#     126 self.stats = {}
#     127 self.sort_arg_dict = {}
# --> 128 self.load_stats(arg)
#     129 try:
# ...
